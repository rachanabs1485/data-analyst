# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()

import io
df = pd.read_csv(io.BytesIO(uploaded['cleaned_data.csv']))
df.head()
# Out:
#      <input type="file" id="files-05d1b5ee-e44c-4d51-bb5c-44570c9a6b34" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05d1b5ee-e44c-4d51-bb5c-44570c9a6b34">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
sns.countplot(x='species', data=df, palette='pastel')
plt.title('Distribution of Species')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipython-input-160605711.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='species', data=df, palette='pastel')

# %%
# This plot is an alternative since the original plot required columns not in the dataset.
df.groupby('species')['sepal_length'].mean().plot(kind='line', marker='o', color='purple')
plt.title('Average Sepal Length by Species')
plt.xlabel('Species')
plt.ylabel('Average Sepal Length')
plt.show()

# %%
# This plot is an alternative since the original plot required columns not in the dataset.
sns.scatterplot(x='sepal_length', y='sepal_width', data=df, hue='species')
plt.title('Sepal Length vs Sepal Width by Species')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

# %%
# This plot is an alternative since the the original plot required a column not in the dataset.
plt.figure(figsize=(6,4))
sns.countplot(x='species', data=df)
plt.title('Distribution of Species')
plt.xlabel('Species')
plt.ylabel('Count')
plt.savefig('species_distribution.png', dpi=300, bbox_inches='tight')
plt.show()
